# %%
# Import Dependencies
import pandas as pd

# %%
CO2_csv = "Resources/owid-co2-data.csv"
co2_df = pd.read_csv(CO2_csv)

co2_df.tail(10)
# Out:
#         country  year iso_code  population           gdp  cement_co2  \
# 46513  Zimbabwe  2012      ZWE  13265331.0  2.090997e+10       0.566
# 46514  Zimbabwe  2013      ZWE  13555420.0  2.112350e+10       0.463
# 46515  Zimbabwe  2014      ZWE  13855758.0  2.122250e+10       0.496
# 46516  Zimbabwe  2015      ZWE  14154937.0  2.102745e+10       0.585
# 46517  Zimbabwe  2016      ZWE  14452705.0  2.096179e+10       0.461
# 46518  Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519  Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520  Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521  Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522  Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 46513                  0.043  11.254           0.891            8.594  ...
# ...

# %%
# reduced file to country, year and co2
reduced_df = co2_df.loc[:,["country", "year", "co2"]]

reduced_df.head(10)
# Out:
#        country  year  co2
# 0  Afghanistan  1850  NaN
# 1  Afghanistan  1851  NaN
# 2  Afghanistan  1852  NaN
# 3  Afghanistan  1853  NaN
# 4  Afghanistan  1854  NaN
# 5  Afghanistan  1855  NaN
# 6  Afghanistan  1856  NaN
# 7  Afghanistan  1857  NaN
# 8  Afghanistan  1858  NaN
# 9  Afghanistan  1859  NaN

# %%
# filter year
reduced_df = reduced_df.loc[(reduced_df["year"] >= 1991) & (reduced_df["year"] <= 2022)]

reduced_df.tail(10)
# Out:
#         country  year     co2
# 46513  Zimbabwe  2012  11.254
# 46514  Zimbabwe  2013  11.671
# 46515  Zimbabwe  2014  11.946
# 46516  Zimbabwe  2015  12.255
# 46517  Zimbabwe  2016  10.533
# 46518  Zimbabwe  2017   9.596
# 46519  Zimbabwe  2018  11.795
# 46520  Zimbabwe  2019  11.115
# 46521  Zimbabwe  2020  10.608
# 46522  Zimbabwe  2021  11.296

# %%
reduced_df.count()
# Out:
# country    8061
# year       8061
# co2        7674
# dtype: int64

# %%
reduced_co2 = reduced_df.dropna(how='any')

# %%
reduced_co2.count()
# Out:
# country    7674
# year       7674
# co2        7674
# dtype: int64

# %%
reduced_co2.dtypes
# Out:
# country     object
# year         int64
# co2        float64
# dtype: object

# %%
reduced_co2 = reduced_co2.rename(columns={'country': 'Country', 'year': 'Reading_date', 'co2': 'CO2_emission'})
reduced_co2
# Out:
#            Country  Reading_date  CO2_emission
# 141    Afghanistan          1991         1.914
# 142    Afghanistan          1992         1.482
# 143    Afghanistan          1993         1.487
# 144    Afghanistan          1994         1.454
# 145    Afghanistan          1995         1.417
# ...            ...           ...           ...
# 46518     Zimbabwe          2017         9.596
# 46519     Zimbabwe          2018        11.795
# 46520     Zimbabwe          2019        11.115
# 46521     Zimbabwe          2020        10.608
# 46522     Zimbabwe          2021        11.296
#
# [7674 rows x 3 columns]

# %%
reduced_co2.to_csv('Resources/reduced_co2.csv', index=False)
